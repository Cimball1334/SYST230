# %% [markdown]
# # Homework Assignment No. 4
# ## SYST 230
# ### Spring 2023

# %% [markdown]
# ## Instructions:
# ---
#
# 1. Homework Guidelines: **Please start your work early as it takes time to understand and debug programs.** Homework assignments may not be completed in a single sitting.
# 2. Homework Deadlines:  You need to complete your work on time. **No extensions** will be given for this assignment.
# 3. Solution Notebooks: Submit your solutions as **Juypter Notebooks**.  Please use this note book as a template. You can **add cells and code** to this note book as needed.
# 5. Naming File for Submission: Name the solution file as **FirstName_LastName_HW#.ipynb** where # is the number of the assignment.
# 6. Test Cases: Please add other test cases as you see fit to demonstrate that your code and functions work.
# 7. You may discuss problems and solution methods with others, but you should not share code with anyone.
# 8. **All homework related issues should be addressed to the class TA**. The class TA, Mr. Babak Aslani, is your instructor in the lab sections.

# %% [markdown]
# ## Coding Problem 1:
# ##### In this question, you are provided with the following arrays that contain electricity usage data for various classes of consumers, e.g., residential, commercial, and industrial. The usage data represents the average US electricity consumption/day for years 2006 to 2020 in the month of July. The average usage data are ) 10^9 kWh/day.
#
#  residential = [ 2.861  3.0484  3.2602  3.342  3.3555  3.4234  3.5268  3.9185  3.9718  3.854  3.8934  4.3127  4.2153  4.1711  4.6605 ]
#
#  commercial = [2.5348  2.553  2.7084  2.8097  2.9167  3.9299  3.6561  3.3057  3.4761  3.4748  3.5968  3.7088  3.7172  3.7257  3.9367]
#
#  industrial =  [2.6408  2.74  2.7345  2.8019  2.796  2.8579  2.8597  2.8757  4.000  3.8998  2.6826  2.8427  2.8301  2.8542  2.8512]
#
# ##### The price data per kWh is given as follows:
# Residential: $0.114 (11.4 cents)
#
# Commercial: $0.1319 (13.9 cents)
#
# Industrial: $0.0672 (6.72 cents)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Your code goes here:
import numpy as np
import matplotlib.pyplot as plt

residential = np.array([2.861, 3.0484, 3.2602, 3.342, 3.3555, 3.4234, 3.5268, 3.9185, 3.9718, 3.854, 3.8934, 4.3127, 4.2153, 4.1711, 4.6605 ])
commercial = np.array([2.5348,  2.553,  2.7084,  2.8097,  2.9167,  3.9299,  3.6561,  3.3057,  3.4761,  3.4748,  3.5968,  3.7088,  3.7172,  3.7257,  3.9367])
industrial = np.array([2.6408,  2.74,  2.7345,  2.8019,  2.796,  2.8579,  2.8597,  2.8757,  4.000,  3.8998,  2.6826,  2.8427,  2.8301,  2.8542,  2.8512])
x_axis = np.arange(2006,2021,1)

rescost = 0.114
comcost = 0.1319
indcost = 0.0672

#task 1

title = "Average US July Electrical Usage (2006-2020)"
plt.title(title)
plt.xlabel('Years')
plt.ylabel('10^9 KWh/day')

plt.plot(x_axis,residential,'g',label='residential')
plt.plot(x_axis,commercial,'b--',label='commercial')
plt.plot(x_axis,industrial,'m-.',label='industrial')

plt.legend()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Your code goes here:


adj = 10**9

print(f'Total cost/day for residential in 2006: {residential[0]*adj*rescost:e}')
print(f'Total cost/day for residential in 2014: {residential[8]*adj*rescost:e}')
print(f'Total cost/day for residential in 2015: {residential[9]*adj*rescost:e}')

print(f'Total cost/day for commercial in 2006: {commercial[0]*adj*comcost:e}')
print(f'Total cost/day for commercial in 2015: {commercial[8]*adj*comcost:e}')
print(f'Total cost/day for commercial in 2014: {commercial[9]*adj*comcost:e}')

print(f'Total cost/day for industrial in 2006: {industrial[0]*adj*indcost:e}')
print(f'Total cost/day for industrial in 2015: {industrial[8]*adj*indcost:e}')
print(f'Total cost/day for industrial in 2014: {industrial[9]*adj*indcost:e}')
# Out:
# Total cost/day for residential in 2006: 3.261540e+08
# Total cost/day for residential in 2014: 4.527852e+08
# Total cost/day for residential in 2015: 4.393560e+08
# Total cost/day for commercial in 2006: 3.343401e+08
# Total cost/day for commercial in 2015: 4.584976e+08
# Total cost/day for commercial in 2014: 4.583261e+08
# Total cost/day for industrial in 2006: 1.774618e+08
# Total cost/day for industrial in 2015: 2.688000e+08
# Total cost/day for industrial in 2014: 2.620666e+08

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Your code goes here:
dif = commercial > industrial
print(f'Commercial usage is higher than industrial in {np.sum(dif)} different years, \nThose years are: {x_axis[dif]}')
# Out:
# Commercial usage is higher than industrial in 10 different years,
# Those years are: [2009 2010 2011 2012 2013 2016 2017 2018 2019 2020]

# %% [markdown]
# ![image.png](attachment:image.png)
#
# * *J = Sum of the Squared Errors (SSE)*

# %%
# Your code goes here:

base = np.arange(len(residential))
coeff = np.polyfit(base,residential,1)
poly = np.poly1d(coeff)

J = sum((poly(base) - residential)**2) / (2 *len(residential) * rescost)

plt.scatter(x_axis,residential,color='red',marker='X',label='Data')
plt.plot(x_axis,poly(base),label='Line of Best Fit')
plt.text(1,1,f'J = {J:.2f} dollars')
plt.legend()
